# %% [markdown]
# # Experimento de extração de arquivos PDF de repositórios digitais
#
# Usa arquivo de resultados exportado pela biblioteca nacional de teses e dissertações
#
# Consulta feita no dia xx/09/2024, limitando a documentos a partir de 2021 e com as mesmas palavras-chave do artigo da Regis.

# %%
# funções usadas no restante do código

import requests, re
import csv, ast, time, pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urlparse

################################################################################

def baixar_pdf(url, nome_arquivo):
    """
    Baixa um PDF de uma URL e salva em um arquivo local.

    Args:
        url: A URL do PDF.
        nome_arquivo: O nome do arquivo local onde o PDF será salvo.
    """

    resposta = requests.get(url)
    resposta.raise_for_status()  # Lança uma exceção se houver um erro na requisição

    with open(nome_arquivo, 'wb') as arquivo:
        arquivo.write(resposta.content)

    print(f"PDF baixado e salvo em: {nome_arquivo}")

################################################################################    

# Função para extrair URLs de uma string usando expressão regular
def extrair_url(texto):
  urls = re.findall(r'https?://[^\s]+', texto)
  return urls

def encontrar_links_pdf(url):
  """
  Encontra links para arquivos PDF em uma página web.

  Args:
    url: A URL da página web.

  Returns:
    Uma lista de links para arquivos PDF.
  """

  response = requests.get(url, verify=False)
  soup = BeautifulSoup(response.content, 'html.parser')

  links_pdf = []

  # Encontra todas as tags <a>
  for link in soup.find_all('a'):
    href = link.get('href')
    if href:
      # Verifica se o link termina com ".pdf" ou se a URL contém ".pdf"
      # alternativamente, se não encontrar, localizar o primeiro com 'bitstream' no meio e download no final
      if href.endswith('.pdf') or re.search(r'\.pdf', href):
        links_pdf.append(href)

  return links_pdf


################################################################################

# %%
# Programa principal

# carrega planilha com resultados gerados pelo catálogo digital

arquivo = "Resultados.xlsx"
dados = pandas.read_excel(arquivo)

dados.head()
# Out:
#                              Autor(a)        ID Lattes do(a) autor(a)  \
# 0             Alzate Rubio, Valentina  Não informado pela instituição
# 1   Cabrera Ruiz, Maria Liceth, 1995-  Não informado pela instituição
# 2  Rojas Caro, Daniel Mauricio, 1996-  Não informado pela instituição
# 3     Cruz, Carolina Barbosa Leite da  Não informado pela instituição
# 4      Barbosa, Theresa Rocco Pereira  Não informado pela instituição
#
#                      Orientadores      ID Lattes dos orientadores  \
# 0  Não informado pela instituição  Não informado pela instituição
# 1  Não informado pela instituição  Não informado pela instituição
# 2  Não informado pela instituição  Não informado pela instituição
# 3  Não informado pela instituição  Não informado pela instituição
# 4  Não informado pela instituição  Não informado pela instituição
#
#                  Membros da banca  ID Lattes dos membros da banca  \
# 0  Não informado pela instituição  Não informado pela instituição
# 1  Não informado pela instituição  Não informado pela instituição
# 2  Não informado pela instituição  Não informado pela instituição
# 3  Não informado pela instituição  Não informado pela instituição
# 4  Não informado pela instituição  Não informado pela instituição
#
#                                               Título  Ano de defesa  \
# 0  CO2 mineralization process in basalt rocks: st...           2024
# 1  Relação entre as propriedades geomecânicas e o...           2022
# 2  Modelo geomecânico dos reservatórios do pré-sa...           2022
# 3  Luminescence signals sensitivity of quartz fro...           2023
# 4  The role of airborne geophysical data as covar...           2023
#
#                          Instituição de defesa Sigla da instituição de defesa  \
# 0              Universidade de São Paulo (USP)                            USP
# 1  Universidade Estadual de Campinas (UNICAMP)                        UNICAMP
# 2  Universidade Estadual de Campinas (UNICAMP)                        UNICAMP
# 3              Universidade de São Paulo (USP)                            USP
# 4   Universidade Federal de Santa Maria (UFSM)                           UFSM
#
#    ...       Área do conhecimento CNPq Tipos de acesso Tipo de documento  \
# 0  ...  Não informado pela instituição      openAccess      masterThesis
# 1  ...  Não informado pela instituição      openAccess      masterThesis
# 2  ...  Não informado pela instituição      openAccess      masterThesis
# 3  ...  Não informado pela instituição      openAccess      masterThesis
# 4  ...  Não informado pela instituição      openAccess      masterThesis
#
#                                Assuntos em português  \
# 0  Basalt's petrography||Carbon capture and geolo...
# 1  Geomecânica||Fácies (Geologia)||Petrofísica||P...
# 2  Geomecânica||Carbonatos||Pré-sal||Falhas (Geol...
# 3  Andes orientais||Bacia do Putumayo||Eastern An...
# 4  Gamaespectrometria||Magnetometria||Dados legad...
#
#                Assuntos em inglês Idioma  \
# 0  Não informado pela instituição    eng
# 1  Não informado pela instituição    por
# 2  Não informado pela instituição    por
# 3  Não informado pela instituição    eng
# 4  Não informado pela instituição    por
#
#                                               Resumo  \
# 0  The Serra Geral Formation basalts, prominent w...
# 1                   Orientador: Alessandro Batezelli
# 2                   Orientador: Alessandro Batezelli
# 3  Sediment provenance analysis is a widely used ...
# 4  A porção sul da Bacia Sedimentar do Paraná tem...
#
#                                       Link de acesso  \
# 0  https://www.teses.usp.br/teses/disponiveis/44/...
# 1  https://hdl.handle.net/20.500.12733/6331||CABR...
# 2  https://hdl.handle.net/20.500.12733/7666||ROJA...
# 3  https://www.teses.usp.br/teses/disponiveis/44/...
# 4          http://repositorio.ufsm.br/handle/1/31268
#
#                  Resumo em Inglês        Referência Bibliográfica
# 0  Não informado pela instituição  Não informado pela instituição
# 1  Não informado pela instituição  Não informado pela instituição
# 2  Não informado pela instituição  Não informado pela instituição
# 3  Não informado pela instituição  Não informado pela instituição
# 4  Não informado pela instituição  Não informado pela instituição
#
# [5 rows x 23 columns]

# %%
# filtra por registros que sejam de acesso aberto e cria dataframe com somente algumas colunas relevantes
dados_acesso_aberto = dados[dados['Tipos de acesso']=="openAccess"]
dados_relevantes = dados_acesso_aberto[['Ano de defesa', 'Sigla da instituição de defesa', 'Tipo de documento', 'Link de acesso']]

# agrupa por instituição (visto que o tipo de informação que cada uma apresenta é diferente)
dados_by_instituicao = dados_relevantes.groupby('Sigla da instituição de defesa')

# para cada grupo, mostra na tela a URL do trabalho na biblioteca original
for nome_grupo, dados_grupo in dados_by_instituicao:
    print(f'Grupo: {nome_grupo}')
    
    for i, reg in dados_grupo.iterrows():
        #TODO: algumas contém mais do que uma URL. Identificar qual usar!!!
        print(f"  URL: {extrair_url(reg['Link de acesso'])}") 

    print('---')
# Out:
# Grupo: CPRM
#   URL: ['https://rigeo.sgb.gov.br/handle/doc/24119']
#   URL: ['https://rigeo.cprm.gov.br/handle/doc/22892']
#   URL: ['https://rigeo.cprm.gov.br/handle/doc/22626']
#   URL: ['https://rigeo.cprm.gov.br/handle/doc/22659']
#   URL: ['https://rigeo.sgb.gov.br/handle/doc/24629']
#   URL: ['https://rigeo.cprm.gov.br/handle/doc/23433']
# ---
# Grupo: CUB
#   URL: ['https://repositorio.cruzeirodosul.edu.br/handle/123456789/3828']
# ---
# Grupo: FEI
#   URL: ['https://doi.org/10.31414/EM.2022.D.131393.||https://doi.org/10.31414/EM.2022.D.131393||https://repositorio.fei.edu.br/handle/FEI/4411']
#   URL: ['https://doi.org/10.31414/EQ.2022.D.131605.||https://doi.org/10.31414/EQ.2022.D.131605||https://repositorio.fei.edu.br/handle/FEI/4737']
#   URL: ['https://doi.org/10.31414/EM.2023.D.131632.||https://doi.org/10.31414/EM.2023.D.131632||https://repositorio.fei.edu.br/handle/FEI/4861']
#   URL: ['https://doi.org/10.31414/EQ.2021.D.131349.||https://doi.org/10.31414/EQ.2021.D.131349||https://repositorio.fei.edu.br/handle/FEI/3275']
# ---
# Grupo: FGV
#   URL: ['https://hdl.handle.net/10438/33610']
#   URL: ['https://hdl.handle.net/10438/34485']
#   URL: ['https://hdl.handle.net/10438/33140']
#   URL: ['https://hdl.handle.net/10438/32467']
#   URL: ['https://hdl.handle.net/10438/33572']
#   URL: ['https://hdl.handle.net/10438/32149']
#   URL: ['https://hdl.handle.net/10438/33223']
#   URL: ['https://hdl.handle.net/10438/30896']
#   URL: ['https://hdl.handle.net/10438/31443']
#   URL: ['https://hdl.handle.net/10438/31668']
# ---
# Grupo: FIOCRUZ
#   URL: ['https://www.arca.fiocruz.br/handle/icict/61147']
# ---
# Grupo: FURG
#   URL: ['http://repositorio.furg.br/handle/1/10403']
# ---
# Grupo: IDP
#   URL: ['https://repositorio.idp.edu.br//handle/123456789/4123']
# ---
# Grupo: INPE
#   URL: ['http://urlib.net/sid.inpe.br/mtc-m21c/2021/03.04.13.54']
# ---
# Grupo: PUC_RIO
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=58981@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=58981@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=57361@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=57361@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=55925@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=55925@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=59524@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=59524@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=59617@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=59617@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=62448@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=62448@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=54148@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=54148@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=53171@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=53171@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=53216@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=53216@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61188@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61188@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=54443@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=54443@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=62851@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=62851@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=59092@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=59092@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61310@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61310@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61488@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61488@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61875@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61875@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=62422@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=62422@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=59412@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=59412@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=60094@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=60094@2']
#   URL: ['https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61838@1||https://www.maxwell.vrac.puc-rio.br/colecao.php?strSecao=resultado&nrSeq=61838@2']
# ---
# Grupo: PUC_RS
#   URL: ['http://tede2.pucrs.br/tede2/handle/tede/9821']
#   URL: ['http://tede2.pucrs.br/tede2/handle/tede/9850']
#   URL: ['http://tede2.pucrs.br/tede2/handle/tede/9854']
#   URL: ['https://tede2.pucrs.br/tede2/handle/tede/10466']
#   URL: ['https://tede2.pucrs.br/tede2/handle/tede/10582']
# ---
# Grupo: PUC_SP
#   URL: ['https://repositorio.pucsp.br/jspui/handle/handle/29540']
#   URL: ['https://repositorio.pucsp.br/jspui/handle/handle/24880']
#   URL: ['https://repositorio.pucsp.br/jspui/handle/handle/29624']
#   URL: ['https://repositorio.pucsp.br/jspui/handle/handle/41323']
# ---
# Grupo: UCS
#   URL: ['https://repositorio.ucs.br/11338/8952']
# ---
# Grupo: UEFS
#   URL: ['http://tede2.uefs.br:8080/handle/tede/1659']
#   URL: ['http://tede2.uefs.br:8080/handle/tede/1454']
# ---
# Grupo: UEG
#   URL: ['http://www.bdtd.ueg.br/handle/tede/1429']
#   URL: ['http://www.bdtd.ueg.br/handle/tede/1440']
#   URL: ['http://www.bdtd.ueg.br/handle/tede/1333']
# ---
# Grupo: UEL
#   URL: ['https://repositorio.uel.br/handle/123456789/8925']
#   URL: ['https://repositorio.uel.br/handle/123456789/10572']
#   URL: ['https://repositorio.uel.br/handle/123456789/8918']
#   URL: ['https://repositorio.uel.br/handle/123456789/15170']
#   URL: ['https://repositorio.uel.br/handle/123456789/10255']
#   URL: ['https://repositorio.uel.br/handle/123456789/12037']
#   URL: ['https://repositorio.uel.br/handle/123456789/11051']
#   URL: ['https://repositorio.uel.br/handle/123456789/9575']
#   URL: ['https://repositorio.uel.br/handle/123456789/12028']
#   URL: ['https://repositorio.uel.br/handle/123456789/16958']
#   URL: ['https://repositorio.uel.br/handle/123456789/10652']
#   URL: ['https://repositorio.uel.br/handle/123456789/8949']
#   URL: ['https://repositorio.uel.br/handle/123456789/10400']
#   URL: ['https://repositorio.uel.br/handle/123456789/12749']
#   URL: ['https://repositorio.uel.br/handle/123456789/9557']
#   URL: ['https://repositorio.uel.br/handle/123456789/11394']
#   URL: ['https://repositorio.uel.br/handle/123456789/15485']
#   URL: ['https://repositorio.uel.br/handle/123456789/16728']
#   URL: ['https://repositorio.uel.br/handle/123456789/11124']
#   URL: ['https://repositorio.uel.br/handle/123456789/8956']
#   URL: ['https://repositorio.uel.br/handle/123456789/11560']
#   URL: ['https://repositorio.uel.br/handle/123456789/15532']
#   URL: ['https://repositorio.uel.br/handle/123456789/11081']
#   URL: ['https://repositorio.uel.br/handle/123456789/16006']
#   URL: ['https://repositorio.uel.br/handle/123456789/9598']
#   URL: ['https://repositorio.uel.br/handle/123456789/10888']
#   URL: ['https://repositorio.uel.br/handle/123456789/251']
#   URL: ['https://repositorio.uel.br/handle/123456789/12613']
#   URL: ['https://repositorio.uel.br/handle/123456789/9390']
#   URL: ['https://repositorio.uel.br/handle/123456789/306']
#   URL: ['https://repositorio.uel.br/handle/123456789/16199']
#   URL: ['https://repositorio.uel.br/handle/123456789/16803']
#   URL: ['https://repositorio.uel.br/handle/123456789/12781']
#   URL: ['https://repositorio.uel.br/handle/123456789/14084']
#   URL: ['https://repositorio.uel.br/handle/123456789/12542']
#   URL: ['https://repositorio.uel.br/handle/123456789/17241']
#   URL: ['https://repositorio.uel.br/handle/123456789/8500']
#   URL: ['https://repositorio.uel.br/handle/123456789/11235']
#   URL: ['https://repositorio.uel.br/handle/123456789/13601']
#   URL: ['https://repositorio.uel.br/handle/123456789/8847']
#   URL: ['https://repositorio.uel.br/handle/123456789/12869']
#   URL: ['https://repositorio.uel.br/handle/123456789/10679']
# ---
# Grupo: UEM
#   URL: ['http://repositorio.uem.br:8080/jspui/handle/1/6247']
#   URL: ['http://repositorio.uem.br:8080/jspui/handle/1/7067']
#   URL: ['http://repositorio.uem.br:8080/jspui/handle/1/6252']
# ---
# Grupo: UEPG
#   URL: ['http://tede2.uepg.br/jspui/handle/prefix/4061']
#   URL: ['http://tede2.uepg.br/jspui/handle/prefix/3812']
#   URL: ['http://tede2.uepg.br/jspui/handle/prefix/4030']
#   URL: ['http://tede2.uepg.br/jspui/handle/prefix/4048']
#   URL: ['http://tede2.uepg.br/jspui/handle/prefix/3641']
#   URL: ['http://tede2.uepg.br/jspui/handle/prefix/3710']
#   URL: ['http://tede2.uepg.br/jspui/handle/prefix/3889']
#   URL: ['http://tede2.uepg.br/jspui/handle/prefix/4133']
# ---
# Grupo: UERJ
#   URL: ['http://www.bdtd.uerj.br/handle/1/20566']
#   URL: ['http://www.bdtd.uerj.br/handle/1/20225']
#   URL: ['http://www.bdtd.uerj.br/handle/1/18876']
#   URL: ['http://www.bdtd.uerj.br/handle/1/17276']
#   URL: ['http://www.bdtd.uerj.br/handle/1/17152']
#   URL: ['http://www.bdtd.uerj.br/handle/1/18940']
#   URL: ['http://www.bdtd.uerj.br/handle/1/17390']
#   URL: ['http://www.bdtd.uerj.br/handle/1/17240']
#   URL: ['http://www.bdtd.uerj.br/handle/1/18086']
#   URL: ['http://www.bdtd.uerj.br/handle/1/17178']
#   URL: ['http://www.bdtd.uerj.br/handle/1/20922']
#   URL: ['http://www.bdtd.uerj.br/handle/1/20831']
#   URL: ['http://www.bdtd.uerj.br/handle/1/19407']
#   URL: ['http://www.bdtd.uerj.br/handle/1/19252']
#   URL: ['http://www.bdtd.uerj.br/handle/1/19755']
#   URL: ['http://www.bdtd.uerj.br/handle/1/19284']
#   URL: ['http://www.bdtd.uerj.br/handle/1/20335']
#   URL: ['http://www.bdtd.uerj.br/handle/1/19790']
#   URL: ['http://www.bdtd.uerj.br/handle/1/20303']
#   URL: ['http://www.bdtd.uerj.br/handle/1/20645']
#   URL: ['http://www.bdtd.uerj.br/handle/1/20070']
#   URL: ['http://www.bdtd.uerj.br/handle/1/17116']
#   URL: ['http://www.bdtd.uerj.br/handle/1/19561']
#   URL: ['http://www.bdtd.uerj.br/handle/1/21047']
#   URL: ['http://www.bdtd.uerj.br/handle/1/18140']
#   URL: ['http://www.bdtd.uerj.br/handle/1/18263']
#   URL: ['http://www.bdtd.uerj.br/handle/1/19825']
#   URL: ['http://www.bdtd.uerj.br/handle/1/19833']
#   URL: ['http://www.bdtd.uerj.br/handle/1/19322']
#   URL: ['http://www.bdtd.uerj.br/handle/1/20027']
#   URL: ['http://www.bdtd.uerj.br/handle/1/20701']
#   URL: ['http://www.bdtd.uerj.br/handle/1/21096']
# ---
# Grupo: UFABC
#   URL: ['http://biblioteca.ufabc.edu.br/index.php?codigo_sophia=122391']
#   URL: ['http://biblioteca.ufabc.edu.br/index.php?codigo_sophia=122549']
#   URL: ['http://biblioteca.ufabc.edu.br/index.php?codigo_sophia=126503']
# ---
# Grupo: UFAM
#   URL: ['https://tede.ufam.edu.br/handle/tede/9572']
#   URL: ['https://tede.ufam.edu.br/handle/tede/10260']
#   URL: ['https://tede.ufam.edu.br/handle/tede/8470']
#   URL: ['https://tede.ufam.edu.br/handle/tede/8638']
#   URL: ['https://tede.ufam.edu.br/handle/tede/8321']
#   URL: ['https://tede.ufam.edu.br/handle/tede/8599']
#   URL: ['https://tede.ufam.edu.br/handle/tede/9509']
# ---
# Grupo: UFBA
#   URL: ['https://repositorio.ufba.br/handle/ri/37191']
#   URL: ['https://repositorio.ufba.br/handle/ri/37303']
#   URL: ['https://repositorio.ufba.br/handle/ri/37190']
#   URL: ['https://repositorio.ufba.br/handle/ri/36002']
#   URL: ['https://repositorio.ufba.br/handle/ri/37718']
#   URL: ['https://repositorio.ufba.br/handle/ri/35752']
#   URL: ['https://repositorio.ufba.br/handle/ri/37057']
#   URL: ['https://repositorio.ufba.br/handle/ri/34754']
#   URL: ['https://repositorio.ufba.br/handle/ri/39502']
#   URL: ['https://repositorio.ufba.br/handle/ri/37865']
#   URL: ['https://repositorio.ufba.br/handle/ri/39198']
#   URL: ['https://repositorio.ufba.br/handle/ri/38438']
#   URL: ['https://repositorio.ufba.br/handle/ri/37758']
#   URL: ['https://repositorio.ufba.br/handle/ri/37044']
#   URL: ['https://repositorio.ufba.br/handle/ri/37072']
#   URL: ['https://repositorio.ufba.br/handle/ri/37054']
#   URL: ['https://repositorio.ufba.br/handle/ri/37071']
#   URL: ['https://repositorio.ufba.br/handle/ri/37196']
#   URL: ['https://repositorio.ufba.br/handle/ri/34750']
#   URL: ['https://repositorio.ufba.br/handle/ri/37304']
#   URL: ['https://repositorio.ufba.br/handle/ri/38756']
#   URL: ['https://repositorio.ufba.br/handle/ri/39082']
#   URL: ['https://repositorio.ufba.br/handle/ri/39379']
#   URL: ['https://repositorio.ufba.br/handle/ri/34764']
#   URL: ['https://repositorio.ufba.br/handle/ri/36438']
#   URL: ['http://repositorio.ufba.br/ri/handle/ri/33462']
#   URL: ['https://repositorio.ufba.br/handle/ri/37713']
#   URL: ['https://repositorio.ufba.br/handle/ri/37195']
#   URL: ['https://repositorio.ufba.br/handle/ri/37108']
#   URL: ['https://repositorio.ufba.br/handle/ri/37955']
#   URL: ['https://repositorio.ufba.br/handle/ri/38050']
#   URL: ['https://repositorio.ufba.br/handle/ri/38524']
#   URL: ['http://repositorio.ufba.br/ri/handle/ri/33819']
#   URL: ['https://repositorio.ufba.br/handle/ri/39631']
#   URL: ['https://repositorio.ufba.br/handle/ri/38905']
#   URL: ['https://repositorio.ufba.br/handle/ri/37029']
#   URL: ['https://repositorio.ufba.br/handle/ri/38759']
#   URL: ['https://repositorio.ufba.br/handle/ri/39290']
#   URL: ['https://repositorio.ufba.br/handle/ri/38893']
#   URL: ['https://repositorio.ufba.br/handle/ri/39254']
#   URL: ['https://repositorio.ufba.br/handle/ri/35092']
#   URL: ['https://repositorio.ufba.br/handle/ri/39900']
#   URL: ['https://repositorio.ufba.br/handle/ri/36727']
#   URL: ['https://repositorio.ufba.br/handle/ri/38176']
#   URL: ['https://repositorio.ufba.br/handle/ri/38522']
#   URL: ['https://repositorio.ufba.br/handle/ri/37610']
#   URL: ['https://repositorio.ufba.br/handle/ri/34967']
#   URL: ['https://repositorio.ufba.br/handle/ri/35036']
# ---
# Grupo: UFCG
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/23925||MOREIRA,', 'http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/23925']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/36515||CAVALCANTI,', 'http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/36515']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/33410||ARAÚJO,']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/30881||GUEDES,']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/33219||ESTEVES,']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/36835||GUEDES']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/27370||ARAGÂO.']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/32119||FIGUEIREDO,']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/26117||CARDOSO,']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/26147||Cirne,', 'http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/26147']
#   URL: ['http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/20432||PALHANO,', 'http://dspace.sti.ufcg.edu.br:8080/jspui/handle/riufcg/20432']
# ---
# Grupo: UFERSA
#   URL: ['https://repositorio.ufersa.edu.br/handle/prefix/7040']
#   URL: ['http://lattes.cnpq.br/9567732690904131||http://lattes.cnpq.br/2926414381278843||MORAIS,', 'https://repositorio.ufersa.edu.br/handle/prefix/8794']
#   URL: ['https://repositorio.ufersa.edu.br/handle/prefix/6831']
#   URL: ['http://lattes.cnpq.br/3801476460958779||http://lattes.cnpq.br/6453039303697433||ASSIS,', 'http://lattes.cnpq.br/1621529280559168||https://repositorio.ufersa.edu.br/handle/prefix/7841']
#   URL: ['https://repositorio.ufersa.edu.br/handle/prefix/6815']
# ---
# Grupo: UFES
#   URL: ['http://repositorio.ufes.br/handle/10/15921']
# ---
# Grupo: UFF
#   URL: ['http://app.uff.br/riuff/handle/1/27901||http://dx.doi.org/10.22409/PPGDOT']
#   URL: ['http://app.uff.br/riuff/handle/1/28558']
#   URL: ['https://app.uff.br/riuff/handle/1/34214']
#   URL: ['https://app.uff.br/riuff/handle/1/33962']
#   URL: ['https://app.uff.br/riuff/handle/1/23773||Aluno']
#   URL: ['http://app.uff.br/riuff/handle/1/30458']
#   URL: ['http://app.uff.br/riuff/handle/1/27911']
#   URL: ['https://app.uff.br/riuff/handle/1/21922||Aluno', 'http://dx.doi.org/10.22409/PPG-MESC.2021.m.04110457840']
#   URL: ['http://app.uff.br/riuff/handle/1/27765']
#   URL: ['http://app.uff.br/riuff/handle/1/27912']
#   URL: ['https://app.uff.br/riuff/handle/1/34212']
#   URL: ['http://app.uff.br/riuff/handle/1/27922||http://dx.doi.org/10.22409/PPGDOT']
#   URL: ['http://app.uff.br/riuff/handle/1/29044']
#   URL: ['https://app.uff.br/riuff/handle/1/32956']
#   URL: ['http://app.uff.br/riuff/handle/1/28055']
#   URL: ['https://app.uff.br/riuff/handle/1/33998']
#   URL: ['https://app.uff.br/riuff/handle/1/34204']
#   URL: ['https://app.uff.br/riuff/handle/1/32960']
#   URL: ['http://app.uff.br/riuff/handle/1/29783']
#   URL: ['https://app.uff.br/riuff/handle/1/32968']
#   URL: ['https://app.uff.br/riuff/handle/1/33999']
#   URL: ['https://app.uff.br/riuff/handle/1/34158']
#   URL: ['http://app.uff.br/riuff/handle/1/32051']
#   URL: ['http://app.uff.br/riuff/handle/1/28077']
#   URL: ['http://app.uff.br/riuff/handle/1/29843']
#   URL: ['https://app.uff.br/riuff/handle/1/33714']
#   URL: ['http://app.uff.br/riuff/handle/1/31389']
#   URL: ['http://app.uff.br/riuff/handle/1/29073']
#   URL: ['http://app.uff.br/riuff/handle/1/27055']
#   URL: ['https://app.uff.br/riuff/handle/1/33848']
#   URL: ['https://app.uff.br/riuff/handle/1/34027']
#   URL: ['https://app.uff.br/riuff/handle/1/34093']
#   URL: ['http://app.uff.br/riuff/handle/1/28556']
#   URL: ['http://app.uff.br/riuff/handle/1/27544']
#   URL: ['http://app.uff.br/riuff/handle/1/27923']
#   URL: ['http://app.uff.br/riuff/handle/1/28768']
#   URL: ['http://app.uff.br/riuff/handle/1/29122']
#   URL: ['http://app.uff.br/riuff/handle/1/28988']
#   URL: ['http://app.uff.br/riuff/handle/1/29832']
#   URL: ['http://app.uff.br/riuff/handle/1/29002']
# ---
# Grupo: UFG
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/11726']
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/13271']
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/12832']
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/12947']
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/11323']
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/12839']
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/12857']
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/12870']
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/11563']
#   URL: ['http://repositorio.bc.ufg.br/tede/handle/tede/11142']
# ---
# Grupo: UFJF
#   URL: ['https://repositorio.ufjf.br/jspui/handle/ufjf/15344']
#   URL: ['https://repositorio.ufjf.br/jspui/handle/ufjf/15149']
#   URL: ['https://repositorio.ufjf.br/jspui/handle/ufjf/16265']
#   URL: ['https://repositorio.ufjf.br/jspui/handle/ufjf/15219']
#   URL: ['https://repositorio.ufjf.br/jspui/handle/ufjf/12686']
#   URL: ['https://repositorio.ufjf.br/jspui/handle/ufjf/13173']
# ---
# Grupo: UFLA
#   URL: ['http://repositorio.ufla.br/jspui/handle/1/46741']
#   URL: ['http://repositorio.ufla.br/jspui/handle/1/49758']
# ---
# Grupo: UFMA
#   URL: ['https://tedebc.ufma.br/jspui/handle/tede/tede/4104']
#   URL: ['https://tedebc.ufma.br/jspui/handle/tede/tede/3731']
#   URL: ['https://tedebc.ufma.br/jspui/handle/tede/tede/5447']
#   URL: ['https://tedebc.ufma.br/jspui/handle/tede/tede/5458']
#   URL: ['https://tedebc.ufma.br/jspui/handle/tede/tede/4903']
#   URL: ['https://tedebc.ufma.br/jspui/handle/tede/tede/5221']
# ---
# Grupo: UFMG
#   URL: ['http://hdl.handle.net/1843/55822']
#   URL: ['http://hdl.handle.net/1843/63180']
#   URL: ['http://hdl.handle.net/1843/40968']
#   URL: ['http://hdl.handle.net/1843/45252']
#   URL: ['http://hdl.handle.net/1843/47031']
#   URL: ['http://hdl.handle.net/1843/57289']
#   URL: ['http://hdl.handle.net/1843/62415']
#   URL: ['http://hdl.handle.net/1843/62265']
#   URL: ['http://hdl.handle.net/1843/44469']
#   URL: ['http://hdl.handle.net/1843/47407']
#   URL: ['http://hdl.handle.net/1843/53884']
#   URL: ['http://hdl.handle.net/1843/58551']
#   URL: ['http://hdl.handle.net/1843/55468']
#   URL: ['http://hdl.handle.net/1843/37145']
#   URL: ['http://hdl.handle.net/1843/54001']
#   URL: ['http://hdl.handle.net/1843/60831']
#   URL: ['http://hdl.handle.net/1843/49390']
#   URL: ['http://hdl.handle.net/1843/51267']
#   URL: ['http://hdl.handle.net/1843/54824']
#   URL: ['http://hdl.handle.net/1843/52457']
#   URL: ['http://hdl.handle.net/1843/52855']
#   URL: ['http://hdl.handle.net/1843/50680']
# ---
# Grupo: UFMS
#   URL: ['https://repositorio.ufms.br/handle/123456789/5832']
#   URL: ['https://repositorio.ufms.br/handle/123456789/4827']
#   URL: ['https://repositorio.ufms.br/handle/123456789/4797']
#   URL: ['https://repositorio.ufms.br/handle/123456789/8242']
#   URL: ['https://repositorio.ufms.br/handle/123456789/8720']
#   URL: ['https://repositorio.ufms.br/handle/123456789/8285']
#   URL: ['https://repositorio.ufms.br/handle/123456789/6398']
# ---
# Grupo: UFMT
#   URL: ['http://ri.ufmt.br/handle/1/5392']
# ---
# Grupo: UFOP
#   URL: ['http://www.repositorio.ufop.br/handle/123456789/13205']
# ---
# Grupo: UFPA
#   URL: ['http://repositorio.ufpa.br:8080/jspui/handle/2011/14999']
#   URL: ['https://repositorio.ufpa.br/jspui/handle/2011/16331']
#   URL: ['https://repositorio.ufpa.br/jspui/handle/2011/16231']
#   URL: ['http://repositorio.ufpa.br:8080/jspui/handle/2011/14796']
#   URL: ['http://repositorio.ufpa.br:8080/jspui/handle/2011/14689']
#   URL: ['https://repositorio.ufpa.br/jspui/handle/2011/16226']
#   URL: ['http://repositorio.ufpa.br:8080/jspui/handle/2011/14723']
#   URL: ['https://repositorio.ufpa.br/jspui/handle/2011/16233']
#   URL: ['http://repositorio.ufpa.br:8080/jspui/handle/2011/15363']
#   URL: ['http://repositorio.ufpa.br:8080/jspui/handle/2011/14826']
#   URL: ['http://repositorio.ufpa.br:8080/jspui/handle/2011/15262']
#   URL: ['https://repositorio.ufpa.br/jspui/handle/2011/15828']
# ---
# Grupo: UFPB
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/21566']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/20933']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/21774']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/30927']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/31058']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/30371']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/22735']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/21459']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/24226']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/31267']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/30079']
#   URL: ['https://repositorio.ufpb.br/jspui/handle/123456789/21305']
# ---
# Grupo: UFPE
#   URL: ['https://repositorio.ufpe.br/handle/123456789/55038']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/52526']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/45837']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/46576']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/48183']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/44627']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/54345']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/55239']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/52046']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/42318']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/45797']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/50739']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/42437']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/54750']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/55521']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/44224']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/49238']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/51310']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/49206']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/54348']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/40721']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/49705']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/42458']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/47991']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/49468']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/41666']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/48236']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/47283']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/45836']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/55623']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/51146']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/50338']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/45620']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/44284']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/47678']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/44723']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/46385']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/42291']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/44288']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/55595']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/49590']
#   URL: ['https://repositorio.ufpe.br/handle/123456789/54075']
# ---
# Grupo: UFPEL
#   URL: ['http://guaiaca.ufpel.edu.br/handle/prefix/7905']
#   URL: ['http://guaiaca.ufpel.edu.br/handle/prefix/8200']
#   URL: ['http://guaiaca.ufpel.edu.br/handle/prefix/8063']
# ---
# Grupo: UFPR
#   URL: ['https://hdl.handle.net/1884/85168']
#   URL: ['https://hdl.handle.net/1884/79864']
#   URL: ['https://hdl.handle.net/1884/82160']
#   URL: ['https://hdl.handle.net/1884/85275']
#   URL: ['https://hdl.handle.net/1884/85988']
#   URL: ['https://hdl.handle.net/1884/71813']
#   URL: ['https://hdl.handle.net/1884/72694']
#   URL: ['https://hdl.handle.net/1884/88181']
#   URL: ['https://hdl.handle.net/1884/83164']
#   URL: ['https://hdl.handle.net/1884/78167']
#   URL: ['https://hdl.handle.net/1884/87195']
#   URL: ['https://hdl.handle.net/1884/72192']
#   URL: ['https://hdl.handle.net/1884/79621']
#   URL: ['https://hdl.handle.net/1884/81464']
#   URL: ['https://hdl.handle.net/1884/85832']
#   URL: ['https://hdl.handle.net/1884/81436']
#   URL: ['https://hdl.handle.net/1884/80391']
#   URL: ['https://hdl.handle.net/1884/72781']
#   URL: ['https://hdl.handle.net/1884/78304']
#   URL: ['https://hdl.handle.net/1884/73656']
#   URL: ['https://hdl.handle.net/1884/80924']
#   URL: ['https://hdl.handle.net/1884/74817']
#   URL: ['https://hdl.handle.net/1884/73483']
#   URL: ['https://hdl.handle.net/1884/85908']
#   URL: ['https://hdl.handle.net/1884/82960']
#   URL: ['https://hdl.handle.net/1884/71927']
#   URL: ['https://hdl.handle.net/1884/85970']
# ---
# Grupo: UFRA
#   URL: ['http://repositorio.ufra.edu.br/jspui/handle/123456789/1845.', 'http://repositorio.ufra.edu.br/jspui/handle/123456789/1845']
#   URL: ['http://repositorio.ufra.edu.br/jspui/handle/123456789/1863', 'http://repositorio.ufra.edu.br/jspui/handle/123456789/1863']
# ---
# Grupo: UFRGS
#   URL: ['http://hdl.handle.net/10183/264230']
#   URL: ['http://hdl.handle.net/10183/275440']
#   URL: ['http://hdl.handle.net/10183/262057']
#   URL: ['http://hdl.handle.net/10183/272971']
#   URL: ['http://hdl.handle.net/10183/273881']
#   URL: ['http://hdl.handle.net/10183/263296']
#   URL: ['http://hdl.handle.net/10183/257744']
#   URL: ['http://hdl.handle.net/10183/259315']
#   URL: ['http://hdl.handle.net/10183/259330']
#   URL: ['http://hdl.handle.net/10183/258637']
#   URL: ['http://hdl.handle.net/10183/225741']
#   URL: ['http://hdl.handle.net/10183/276599']
#   URL: ['http://hdl.handle.net/10183/273194']
#   URL: ['http://hdl.handle.net/10183/222087']
#   URL: ['http://hdl.handle.net/10183/257477']
#   URL: ['http://hdl.handle.net/10183/220455']
#   URL: ['http://hdl.handle.net/10183/258810']
#   URL: ['http://hdl.handle.net/10183/267586']
#   URL: ['http://hdl.handle.net/10183/273172']
#   URL: ['http://hdl.handle.net/10183/221993']
#   URL: ['http://hdl.handle.net/10183/241094']
#   URL: ['http://hdl.handle.net/10183/277547']
#   URL: ['http://hdl.handle.net/10183/241911']
#   URL: ['http://hdl.handle.net/10183/274051']
#   URL: ['http://hdl.handle.net/10183/259335']
#   URL: ['http://hdl.handle.net/10183/273011']
#   URL: ['http://hdl.handle.net/10183/273898']
#   URL: ['http://hdl.handle.net/10183/263289']
#   URL: ['http://hdl.handle.net/10183/225647']
#   URL: ['http://hdl.handle.net/10183/254356']
#   URL: ['http://hdl.handle.net/10183/258633']
#   URL: ['http://hdl.handle.net/10183/248656']
#   URL: ['http://hdl.handle.net/10183/249078']
#   URL: ['http://hdl.handle.net/10183/236295']
#   URL: ['http://hdl.handle.net/10183/272065']
#   URL: ['http://hdl.handle.net/10183/267589']
#   URL: ['http://hdl.handle.net/10183/258786']
#   URL: ['http://hdl.handle.net/10183/263305']
#   URL: ['http://hdl.handle.net/10183/259354']
#   URL: ['http://hdl.handle.net/10183/258734']
#   URL: ['http://hdl.handle.net/10183/239666']
#   URL: ['http://hdl.handle.net/10183/264021']
#   URL: ['http://hdl.handle.net/10183/217632']
#   URL: ['http://hdl.handle.net/10183/223649']
#   URL: ['http://hdl.handle.net/10183/263711']
#   URL: ['http://hdl.handle.net/10183/264301']
#   URL: ['http://hdl.handle.net/10183/231561']
#   URL: ['http://hdl.handle.net/10183/226204']
#   URL: ['http://hdl.handle.net/10183/263280']
#   URL: ['http://hdl.handle.net/10183/263999']
#   URL: ['http://hdl.handle.net/10183/235530']
#   URL: ['http://hdl.handle.net/10183/237480']
#   URL: ['http://hdl.handle.net/10183/221996']
#   URL: ['http://hdl.handle.net/10183/272147']
#   URL: ['http://hdl.handle.net/10183/276067']
#   URL: ['http://hdl.handle.net/10183/257709']
#   URL: ['http://hdl.handle.net/10183/237484']
#   URL: ['http://hdl.handle.net/10183/255322']
# ---
# Grupo: UFRN
#   URL: ['https://repositorio.ufrn.br/handle/123456789/51374']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/57887']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/50091']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/51177']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/43724']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/49491']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/45438']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/52769']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/43127']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/33212']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/45437']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/45471']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/51301']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/47008']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/49886']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/54571']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/54358']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/45696']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/49986']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/47037']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/52813']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/50838']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/32249']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/46833']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/48235']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/56773']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/32910']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/49714']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/49553']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/45664']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/50853']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/46921']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/49236']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/46537']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/32638']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/49287']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/58180']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/46709']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/48400']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/52138']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/51945']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/46805']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/53241']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/47536']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/53345']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/32251']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/47132']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/56568']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/58215']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/47047']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/53029']
#   URL: ['https://repositorio.ufrn.br/handle/123456789/54707']
# ---
# Grupo: UFRPE
#   URL: ['http://www.tede2.ufrpe.br:8080/tede2/handle/tede2/8717']
#   URL: ['http://www.tede2.ufrpe.br:8080/tede2/handle/tede2/8715']
#   URL: ['http://www.tede2.ufrpe.br:8080/tede2/handle/tede2/8772']
# ---
# Grupo: UFRR
#   URL: ['http://repositorio.ufrr.br:8080/jspui/handle/prefix/852']
# ---
# Grupo: UFRRJ
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/15757']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/17724']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/17679']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/13373']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/15844']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/12054']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/17683']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/13338']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/17602']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/9055']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/17639']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/17726']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/9014']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/9217']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/9009']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/9050']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/17670']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/9048']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/10582']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/14312']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/10267']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/9216']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/13305']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/10783']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/14653']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/15825']
#   URL: ['https://rima.ufrrj.br/jspui/handle/20.500.14407/17617']
# ---
# Grupo: UFS
#   URL: ['http://ri.ufs.br/jspui/handle/riufs/16915']
#   URL: ['http://ri.ufs.br/jspui/handle/riufs/17534']
#   URL: ['https://ri.ufs.br/jspui/handle/riufs/17818']
#   URL: ['http://ri.ufs.br/jspui/handle/riufs/16057']
#   URL: ['http://ri.ufs.br/jspui/handle/riufs/17495']
#   URL: ['https://ri.ufs.br/jspui/handle/riufs/14373']
# ---
# Grupo: UFSC
#   URL: ['https://repositorio.ufsc.br/handle/123456789/235100']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/250019']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/249934']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/243727']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/247805']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/251316']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/251207']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/234551']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/243844']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/249785']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/252296']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/244443']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/227091']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/251949']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/244566']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/251144']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/227012']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/249973']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/229886']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/238192']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/247281']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/222073']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/227076']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/254863']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/229761']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/242676']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/252337']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/250174']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/253473']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/229784']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/255051']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/254626']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/254198']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/229183']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/238317']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/229208']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/249949']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/226884']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/230897']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/226844']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/252953']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/251511']
#   URL: ['https://repositorio.ufsc.br/handle/123456789/236183']
# ---
# Grupo: UFSCAR
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/14428']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/18744']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/15769']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/16990']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/19286']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/16099']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/19089']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/14743']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/14099']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/18070']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/17894']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/14526']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/15691']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/17106']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/18586']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/15122']
#   URL: ['https://repositorio.ufscar.br/handle/ufscar/15574']
# ---
# Grupo: UFSM
#   URL: ['http://repositorio.ufsm.br/handle/1/31268']
#   URL: ['http://repositorio.ufsm.br/handle/1/32137']
#   URL: ['http://repositorio.ufsm.br/handle/1/24583']
#   URL: ['http://repositorio.ufsm.br/handle/1/25866']
#   URL: ['http://repositorio.ufsm.br/handle/1/27388']
#   URL: ['http://repositorio.ufsm.br/handle/1/31388']
#   URL: ['http://repositorio.ufsm.br/handle/1/28127']
#   URL: ['http://repositorio.ufsm.br/handle/1/28547']
#   URL: ['http://repositorio.ufsm.br/handle/1/26823']
#   URL: ['http://repositorio.ufsm.br/handle/1/23384']
#   URL: ['http://repositorio.ufsm.br/handle/1/25193']
#   URL: ['http://repositorio.ufsm.br/handle/1/25890']
#   URL: ['http://repositorio.ufsm.br/handle/1/32035']
#   URL: ['http://repositorio.ufsm.br/handle/1/23167']
#   URL: ['http://repositorio.ufsm.br/handle/1/22487']
#   URL: ['http://repositorio.ufsm.br/handle/1/24580']
# ---
# Grupo: UFT
#   URL: ['http://hdl.handle.net/11612/2833']
#   URL: ['http://hdl.handle.net/11612/5282']
#   URL: ['http://hdl.handle.net/11612/5369']
# ---
# Grupo: UFU
#   URL: ['http://doi.org/10.14393/ufu.di.2021.658.||https://repositorio.ufu.br/handle/123456789/33844||http://doi.org/10.14393/ufu.di.2021.658']
#   URL: ['http://doi.org/10.14393/ufu.di.2022.5047.||https://repositorio.ufu.br/handle/123456789/35470||http://doi.org/10.14393/ufu.di.2022.5047']
#   URL: ['http://doi.org/10.14393/ufu.te.2021.321||https://repositorio.ufu.br/handle/123456789/32693||http://doi.org/10.14393/ufu.te.2021.321']
# ---
# Grupo: UFV
#   URL: ['https://locus.ufv.br//handle/123456789/31366']
#   URL: ['https://locus.ufv.br//handle/123456789/29980']
#   URL: ['https://locus.ufv.br//handle/123456789/29526']
#   URL: ['https://locus.ufv.br//handle/123456789/28192']
#   URL: ['https://locus.ufv.br//handle/123456789/30511']
#   URL: ['https://locus.ufv.br//handle/123456789/31475']
#   URL: ['https://locus.ufv.br//handle/123456789/29496']
#   URL: ['https://locus.ufv.br//handle/123456789/30918']
#   URL: ['https://locus.ufv.br//handle/123456789/31702']
#   URL: ['https://locus.ufv.br//handle/123456789/30163']
#   URL: ['https://locus.ufv.br//handle/123456789/31698']
#   URL: ['https://locus.ufv.br//handle/123456789/32114']
#   URL: ['https://locus.ufv.br//handle/123456789/31417']
#   URL: ['https://locus.ufv.br//handle/123456789/31931']
#   URL: ['https://locus.ufv.br//handle/123456789/31473']
# ---
# Grupo: UFVJM
#   URL: ['http://acervo.ufvjm.edu.br/jspui/handle/1/2923']
# ---
# Grupo: UNB
#   URL: ['https://repositorio.unb.br/handle/10482/43389']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/49955']
#   URL: ['https://repositorio.unb.br/handle/10482/44280']
#   URL: ['https://repositorio.unb.br/handle/10482/44640']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/49953']
#   URL: ['https://repositorio.unb.br/handle/10482/43203']
#   URL: ['https://repositorio.unb.br/handle/10482/41456']
#   URL: ['https://repositorio.unb.br/handle/10482/45032']
#   URL: ['https://repositorio.unb.br/handle/10482/43251']
#   URL: ['https://repositorio.unb.br/handle/10482/45464']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/49442']
#   URL: ['https://repositorio.unb.br/handle/10482/44271']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/49945']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/48305']
#   URL: ['https://repositorio.unb.br/handle/10482/44451']
#   URL: ['https://repositorio.unb.br/handle/10482/43721']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/48311']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/50109']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/49951']
#   URL: ['https://repositorio.unb.br/handle/10482/42824']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/49253']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/46179']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/49248']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/47744']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/48457']
#   URL: ['https://repositorio.unb.br/handle/10482/42783']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/45943']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/49369']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/48705']
#   URL: ['https://repositorio.unb.br/handle/10482/42382']
#   URL: ['https://repositorio.unb.br/handle/10482/42515']
#   URL: ['https://repositorio.unb.br/handle/10482/43038']
#   URL: ['http://repositorio.unb.br/handle/10482/50244']
#   URL: ['https://repositorio.unb.br/handle/10482/44755']
#   URL: ['http://repositorio2.unb.br/jspui/handle/10482/46468']
# ---
# Grupo: UNESP
#   URL: ['http://hdl.handle.net/11449/204328||33004137036P9']
#   URL: ['http://hdl.handle.net/11449/235902||33004137036P9']
#   URL: ['https://hdl.handle.net/11449/252939||3082093660327261||0000-0003-0729-2280']
#   URL: ['http://hdl.handle.net/11449/234737||33004137036P9']
#   URL: ['http://hdl.handle.net/11449/244200||33004137036P9']
#   URL: ['http://hdl.handle.net/11449/215813||33004137036P9']
#   URL: ['https://hdl.handle.net/11449/251837||1094173509043048||0000-0002-8895-3740']
#   URL: ['http://hdl.handle.net/11449/250735||33004145083P2']
#   URL: ['https://hdl.handle.net/11449/252055||5677194266761704||0000-0001-7857-060X']
#   URL: ['http://hdl.handle.net/11449/235150||33004137036P9']
#   URL: ['http://hdl.handle.net/11449/244113||33004137036P9']
#   URL: ['http://hdl.handle.net/11449/216325||33004137036P9']
#   URL: ['https://hdl.handle.net/11449/257012||33004048023P9||1365847815463627||0000-0002-9801-0324']
#   URL: ['https://hdl.handle.net/11449/251269']
#   URL: ['https://hdl.handle.net/11449/253506']
#   URL: ['http://hdl.handle.net/11449/242632||33004129042P3']
#   URL: ['http://hdl.handle.net/11449/210920||33004137036P9']
#   URL: ['http://hdl.handle.net/11449/215605||33004137036P9']
#   URL: ['https://hdl.handle.net/11449/253288||https://lattes.cnpq.br/1040111624568359||0000-0001-8193-9017']
#   URL: ['http://hdl.handle.net/11449/204658||33004145070P8']
#   URL: ['http://hdl.handle.net/11449/250643||33004129047P5']
#   URL: ['http://hdl.handle.net/11449/215767||33004137036P9']
#   URL: ['http://hdl.handle.net/11449/216046||33004161001P7']
#   URL: ['https://hdl.handle.net/11449/253228||9702828607543614||0000-0001-8588-5175']
#   URL: ['https://hdl.handle.net/11449/252536']
#   URL: ['http://hdl.handle.net/11449/213717||33004102071P2']
#   URL: ['http://hdl.handle.net/11449/202736||33004129042P3']
#   URL: ['http://hdl.handle.net/11449/243769||33004099082P2']
#   URL: ['http://hdl.handle.net/11449/215139||33004056080P8']
#   URL: ['http://hdl.handle.net/11449/243514||33004048023P9']
#   URL: ['http://hdl.handle.net/11449/250503||33004013069P2']
#   URL: ['https://hdl.handle.net/11449/254964']
#   URL: ['http://hdl.handle.net/11449/217205||33004137036P9']
#   URL: ['http://hdl.handle.net/11449/216881||33004129042P3']
#   URL: ['http://hdl.handle.net/11449/204801||33004102071P2']
#   URL: ['http://hdl.handle.net/11449/234523||33004110040P5']
#   URL: ['http://hdl.handle.net/11449/215049||33004153077P8']
#   URL: ['http://hdl.handle.net/11449/214598||33004080052P0']
#   URL: ['http://hdl.handle.net/11449/216013||33004137036P9']
#   URL: ['http://hdl.handle.net/11449/235670||33004030055P6']
#   URL: ['http://hdl.handle.net/11449/237263||33004080027P6']
#   URL: ['http://hdl.handle.net/11449/243293||33004161001P7']
#   URL: ['http://hdl.handle.net/11449/204443||33004013068P6']
#   URL: ['https://hdl.handle.net/11449/252257||5282208917819723']
#   URL: ['http://hdl.handle.net/11449/214701||33004137041P2']
#   URL: ['http://hdl.handle.net/11449/216272||33004129042P3']
#   URL: ['http://hdl.handle.net/11449/234558||33004080027P6']
#   URL: ['http://hdl.handle.net/11449/215805||33004137041P2']
# ---
# Grupo: UNICAMP
#   URL: ['https://hdl.handle.net/20.500.12733/6331||CABRERA', 'https://hdl.handle.net/20.500.12733/6331.']
#   URL: ['https://hdl.handle.net/20.500.12733/7666||ROJAS', 'https://hdl.handle.net/20.500.12733/7666.']
#   URL: ['https://hdl.handle.net/20.500.12733/5231||CORRÊA,', 'https://hdl.handle.net/20.500.12733/5231.']
#   URL: ['https://hdl.handle.net/20.500.12733/17405||PEREIRA,', 'https://hdl.handle.net/20.500.12733/17405.']
#   URL: ['https://hdl.handle.net/20.500.12733/12742||MARTELLI,', 'https://hdl.handle.net/20.500.12733/12742.']
#   URL: ['https://hdl.handle.net/20.500.12733/3031||MATA,', 'https://hdl.handle.net/20.500.12733/3031.']
#   URL: ['https://hdl.handle.net/20.500.12733/5791||PAEZ', 'https://hdl.handle.net/20.500.12733/5791.']
#   URL: ['https://hdl.handle.net/20.500.12733/5927||MENEGUESSO,', 'https://hdl.handle.net/20.500.12733/5927.']
#   URL: ['https://hdl.handle.net/20.500.12733/7300||BATISTA', 'https://hdl.handle.net/20.500.12733/7300.']
#   URL: ['https://hdl.handle.net/20.500.12733/17009||VARGAS,', 'https://hdl.handle.net/20.500.12733/17009.']
#   URL: ['https://hdl.handle.net/20.500.12733/8904||SILVA,', 'https://hdl.handle.net/20.500.12733/8904.']
#   URL: ['https://hdl.handle.net/20.500.12733/15306||BAHÚ,', 'https://hdl.handle.net/20.500.12733/15306.']
#   URL: ['https://hdl.handle.net/20.500.12733/19999||PÓVOA,', 'https://hdl.handle.net/20.500.12733/19999.']
#   URL: ['https://hdl.handle.net/20.500.12733/5634||ALMEIDA,', 'https://hdl.handle.net/20.500.12733/5634.']
#   URL: ['https://hdl.handle.net/20.500.12733/13788||CAMPOS,', 'https://hdl.handle.net/20.500.12733/13788.']
#   URL: ['https://hdl.handle.net/20.500.12733/1641350||SILVA,', 'https://hdl.handle.net/20.500.12733/1641350.']
#   URL: ['https://hdl.handle.net/20.500.12733/13306||SILVA,', 'https://hdl.handle.net/20.500.12733/13306.']
#   URL: ['https://hdl.handle.net/20.500.12733/10300||SCALABRIN,', 'https://hdl.handle.net/20.500.12733/10300.']
#   URL: ['https://hdl.handle.net/20.500.12733/1642074||HOHENDORFF', 'https://hdl.handle.net/20.500.12733/1642074.']
#   URL: ['https://hdl.handle.net/20.500.12733/1641476||LEMOS,', 'https://hdl.handle.net/20.500.12733/1641476.']
#   URL: ['https://hdl.handle.net/20.500.12733/6813||MARTINS,', 'https://hdl.handle.net/20.500.12733/6813.']
#   URL: ['https://hdl.handle.net/20.500.12733/7592||MACHADO,', 'https://hdl.handle.net/20.500.12733/7592.']
#   URL: ['https://hdl.handle.net/20.500.12733/12280||SOMASCHINI,', 'https://hdl.handle.net/20.500.12733/12280.']
#   URL: ['https://hdl.handle.net/20.500.12733/18598||HERRERA', 'https://hdl.handle.net/20.500.12733/18598.']
#   URL: ['https://hdl.handle.net/20.500.12733/1641246||PEDREIRA,', 'https://hdl.handle.net/20.500.12733/1641246.']
#   URL: ['https://hdl.handle.net/20.500.12733/1640995||GIORDANO,', 'https://hdl.handle.net/20.500.12733/1640995.']
#   URL: ['https://hdl.handle.net/20.500.12733/1641284||JURADO', 'https://hdl.handle.net/20.500.12733/1641284.']
#   URL: ['https://hdl.handle.net/20.500.12733/6894||MEDEIROS,', 'https://hdl.handle.net/20.500.12733/6894.']
#   URL: ['https://hdl.handle.net/20.500.12733/10472||LOPES,', 'https://hdl.handle.net/20.500.12733/10472.']
#   URL: ['https://hdl.handle.net/20.500.12733/19913||MENDES,', 'https://hdl.handle.net/20.500.12733/19913.']
#   URL: ['https://hdl.handle.net/20.500.12733/1641133||OLIVEIRA,', 'https://hdl.handle.net/20.500.12733/1641133.']
#   URL: ['https://hdl.handle.net/20.500.12733/19185||SALES,', 'https://hdl.handle.net/20.500.12733/19185.']
#   URL: ['https://hdl.handle.net/20.500.12733/12055||ARRONE,', 'https://hdl.handle.net/20.500.12733/12055.']
#   URL: ['https://hdl.handle.net/20.500.12733/17939||LEAL,', 'https://hdl.handle.net/20.500.12733/17939.']
#   URL: ['https://hdl.handle.net/20.500.12733/5042||FERNANDEZ', 'https://hdl.handle.net/20.500.12733/5042.']
#   URL: ['https://hdl.handle.net/20.500.12733/6359||LOZADA', 'https://hdl.handle.net/20.500.12733/6359.']
#   URL: ['https://hdl.handle.net/20.500.12733/15480||MIGUEL,', 'https://hdl.handle.net/20.500.12733/15480.']
#   URL: ['https://hdl.handle.net/20.500.12733/15826||OLIVEIRA,', 'https://hdl.handle.net/20.500.12733/15826.']
#   URL: ['https://hdl.handle.net/20.500.12733/19889||LÁZARO,', 'https://hdl.handle.net/20.500.12733/19889.']
#   URL: ['https://hdl.handle.net/20.500.12733/5957||CLEMENTE,', 'https://hdl.handle.net/20.500.12733/5957.']
#   URL: ['https://hdl.handle.net/20.500.12733/394||SIMAS,', 'https://hdl.handle.net/20.500.12733/394.']
#   URL: ['https://hdl.handle.net/20.500.12733/7136||CARPI,', 'https://hdl.handle.net/20.500.12733/7136.']
#   URL: ['https://hdl.handle.net/20.500.12733/8439||PERISSINOTTO,', 'https://hdl.handle.net/20.500.12733/8439.']
#   URL: ['https://hdl.handle.net/20.500.12733/12093||MORATORI,', 'https://hdl.handle.net/20.500.12733/12093.']
#   URL: ['https://hdl.handle.net/20.500.12733/16302||LIMA,', 'https://hdl.handle.net/20.500.12733/16302.']
#   URL: ['https://hdl.handle.net/20.500.12733/1642014||SILVA,', 'https://hdl.handle.net/20.500.12733/1642014.']
#   URL: ['https://hdl.handle.net/20.500.12733/1642194||DANIEL,', 'https://hdl.handle.net/20.500.12733/1642194.']
#   URL: ['https://hdl.handle.net/20.500.12733/1642213||FERREIRA,', 'https://hdl.handle.net/20.500.12733/1642213.']
#   URL: ['https://hdl.handle.net/20.500.12733/4731||SILVA,', 'https://hdl.handle.net/20.500.12733/4731.']
#   URL: ['https://hdl.handle.net/20.500.12733/5638||LEANDRO,', 'https://hdl.handle.net/20.500.12733/5638.']
#   URL: ['https://hdl.handle.net/20.500.12733/6545||MAGRI,', 'https://hdl.handle.net/20.500.12733/6545.']
#   URL: ['https://hdl.handle.net/20.500.12733/7486||ZAGATO,', 'https://hdl.handle.net/20.500.12733/7486.']
#   URL: ['https://hdl.handle.net/20.500.12733/15025||FREITAS,', 'https://hdl.handle.net/20.500.12733/15025.']
#   URL: ['https://hdl.handle.net/20.500.12733/11770||MARINHO,', 'https://hdl.handle.net/20.500.12733/11770.']
#   URL: ['https://hdl.handle.net/20.500.12733/18644||CIA,', 'https://hdl.handle.net/20.500.12733/18644.']
#   URL: ['https://hdl.handle.net/20.500.12733/2254||PIRES-OLIVEIRA,', 'https://hdl.handle.net/20.500.12733/2254.']
# ---
# Grupo: UNICAP
#   URL: ['http://tede2.unicap.br:8080/handle/tede/1629']
#   URL: ['http://tede2.unicap.br:8080/handle/tede/1680']
#   URL: ['http://tede2.unicap.br:8080/handle/tede/1816']
#   URL: ['http://tede2.unicap.br:8080/handle/tede/1688']
#   URL: ['http://tede2.unicap.br:8080/handle/tede/1407']
#   URL: ['http://tede2.unicap.br:8080/handle/tede/1871']
# ---
# Grupo: UNICENTRO
#   URL: ['http://tede.unicentro.br:8080/jspui/handle/jspui/1764']
# ---
# Grupo: UNICSUL
#   URL: ['https://repositorio.cruzeirodosul.edu.br/handle/123456789/3828']
# ---
# Grupo: UNIFEI
#   URL: ['https://repositorio.unifei.edu.br/jspui/handle/123456789/3447']
#   URL: ['https://repositorio.unifei.edu.br/jspui/handle/123456789/3370']
#   URL: ['https://repositorio.unifei.edu.br/jspui/handle/123456789/3891']
#   URL: ['https://repositorio.unifei.edu.br/jspui/handle/123456789/3203']
#   URL: ['https://repositorio.unifei.edu.br/jspui/handle/123456789/4062']
#   URL: ['https://repositorio.unifei.edu.br/jspui/handle/123456789/3332']
#   URL: ['https://repositorio.unifei.edu.br/jspui/handle/123456789/3906']
#   URL: ['https://repositorio.unifei.edu.br/jspui/handle/123456789/3893']
# ---
# Grupo: UNIFESP
#   URL: ['https://repositorio.unifesp.br/11600/67335']
#   URL: ['https://repositorio.unifesp.br/xmlui/handle/11600/62081']
#   URL: ['https://repositorio.unifesp.br/xmlui/handle/11600/62501']
# ---
# Grupo: UNINOVE
#   URL: ['http://bibliotecatede.uninove.br/handle/tede/3443']
#   URL: ['http://bibliotecatede.uninove.br/handle/tede/2804']
# ---
# Grupo: UNIOESTE
#   URL: ['https://tede.unioeste.br/handle/tede/5926']
#   URL: ['https://tede.unioeste.br/handle/tede/6267']
#   URL: ['https://tede.unioeste.br/handle/tede/6340']
#   URL: ['https://tede.unioeste.br/handle/tede/6441']
#   URL: ['http://tede.unioeste.br/handle/tede/5761']
# ---
# Grupo: UNISINOS
#   URL: ['http://www.repositorio.jesuita.org.br/handle/UNISINOS/12441']
#   URL: ['http://www.repositorio.jesuita.org.br/handle/UNISINOS/12522']
#   URL: ['http://www.repositorio.jesuita.org.br/handle/UNISINOS/10295']
#   URL: ['http://www.repositorio.jesuita.org.br/handle/UNISINOS/11889']
#   URL: ['http://repositorio.jesuita.org.br/handle/UNISINOS/12866']
#   URL: ['http://www.repositorio.jesuita.org.br/handle/UNISINOS/11324']
#   URL: ['http://www.repositorio.jesuita.org.br/handle/UNISINOS/11809']
#   URL: ['http://www.repositorio.jesuita.org.br/handle/UNISINOS/10936']
# ---
# Grupo: UNITAU
#   URL: ['http://repositorio.unitau.br/jspui/handle/20.500.11874/6989']
# ---
# Grupo: USP
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44142/tde-06032024-074438/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44142/tde-12122023-081054/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/106/106131/tde-05012022-174759/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3134/tde-03012024-123417/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3134/tde-05072023-094631/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44143/tde-06032023-093131/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/106/106134/tde-21042021-140539/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44143/tde-04082023-072802/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44141/tde-28062023-081718/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/76/76133/tde-19072022-120609/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3133/tde-11052023-080246/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/14/14132/tde-31052024-163112/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3133/tde-21122021-112341/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/85/85131/tde-28032024-072459/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/42/42132/tde-11102022-172512/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/81/81133/tde-01072022-115459/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44137/tde-18012022-122057/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44142/tde-06102023-120544/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3150/tde-03012024-143542/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3134/tde-22082023-100951/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/14/14132/tde-26042022-204518/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/14/14132/tde-05012024-170339/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44141/tde-16062023-080854/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44141/tde-18012022-131202/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/14/14132/tde-12072023-170018/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44142/tde-04082023-124159/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44143/tde-20102022-081015/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/14/14132/tde-26082022-155519/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/18/18158/tde-02012024-171621/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3137/tde-26042023-135519/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/21/21137/tde-19102022-143532/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44141/tde-20062024-090855/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44141/tde-29012024-120216/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3135/tde-22022022-092113/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3134/tde-06052024-085248/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3150/tde-26082024-105205/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/76/76133/tde-17082022-082413/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44143/tde-07062021-083043/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44144/tde-07062024-072100/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/97/97140/tde-12012024-123338/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/8/8136/tde-27022023-181856/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3134/tde-26082022-083727/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3150/tde-15082023-094336/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3135/tde-11012022-123542/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/55/55134/tde-04062024-085711/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/21/21136/tde-30092022-144203/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3134/tde-15022024-104316/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3150/tde-10082021-144303/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/85/85131/tde-08092021-134533/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3147/tde-26082024-131935/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3134/tde-23032023-074058/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/8/8136/tde-17052021-184750/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3133/tde-17072023-091725/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3134/tde-12082022-080122/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3135/tde-28032022-142557/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/60/60134/tde-30092021-161257/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/18/18139/tde-27032023-104419/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44141/tde-16062023-075319/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/11/11140/tde-14022022-170432/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/11/11150/tde-16052023-112317/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3137/tde-12082022-131506/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/17/17138/tde-11042022-112439/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/11/11138/tde-07072023-150316/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3137/tde-05072023-141759/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/48/48134/tde-29112021-115100/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44144/tde-21022022-080150/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44141/tde-23112023-082355/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/11/11140/tde-21052021-084653/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/11/11140/tde-23032023-161926/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44137/tde-17112023-082851/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44144/tde-15092022-111713/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/11/11140/tde-12042022-162844/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/14/14132/tde-12062024-120232/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/14/14132/tde-10082023-122114/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/44/44138/tde-07122023-082334/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/85/85134/tde-28122023-103645/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/96/96133/tde-25072024-142647/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/43/43134/tde-30012024-170938/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/85/85134/tde-23122022-150646/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3137/tde-16032022-134640/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/106/106133/tde-16062023-182310/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3145/tde-14022022-100213/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3135/tde-12072024-075152/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/21/21137/tde-07022024-114941/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/74/74132/tde-07072023-111051/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/85/85134/tde-28032024-105729/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/76/76132/tde-17082022-083929/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/3/3137/tde-12072023-142952/']
#   URL: ['https://www.teses.usp.br/teses/disponiveis/74/74132/tde-16082022-150357/']
# ---
# Grupo: UTFPR
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/31241']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/29708']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/27585']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/27981']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/30909']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/29643']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/29716']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/24500']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/25451']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/27777']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/30024']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/27979']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/30614']
#   URL: ['http://repositorio.utfpr.edu.br/jspui/handle/1/30670']
# ---

# %%
# teste para recuperar somente os dados de um dos grupos
primeiro_grupo = dados_by_instituicao.get_group(list(dados_by_instituicao.groups.keys())[0])
primeiro_grupo
# Out:
#      Ano de defesa Sigla da instituição de defesa Tipo de documento  \
# 30            2023                           CPRM    doctoralThesis
# 45            2022                           CPRM      masterThesis
# 55            2021                           CPRM      masterThesis
# 56            2021                           CPRM      masterThesis
# 79            2023                           CPRM      masterThesis
# 147           2022                           CPRM    doctoralThesis
#
#                                  Link de acesso
# 30    https://rigeo.sgb.gov.br/handle/doc/24119
# 45   https://rigeo.cprm.gov.br/handle/doc/22892
# 55   https://rigeo.cprm.gov.br/handle/doc/22626
# 56   https://rigeo.cprm.gov.br/handle/doc/22659
# 79    https://rigeo.sgb.gov.br/handle/doc/24629
# 147  https://rigeo.cprm.gov.br/handle/doc/23433

# %%
# teste para recuperar a url do primeiro registro do primeiro grupo
list(primeiro_grupo['Link de acesso'])[0]
# Out:
# 'https://rigeo.sgb.gov.br/handle/doc/24119'

# %%
# Analisa a página do primeiro elemento do primeiro grupo, localiza as URLs dos PDFs e mostra na tela 

url = list(primeiro_grupo['Link de acesso'])[0] # Substitua pela URL desejada
links = encontrar_links_pdf(url)  
parsed_url = urlparse(url)
servidor = parsed_url.netloc
for link in links:
  print(f"https://{servidor}{link}")
# Out:
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'rigeo.sgb.gov.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# https://rigeo.sgb.gov.br/bitstream/doc/24119/1/tese__diener_fernando.pdf
# https://rigeo.sgb.gov.br/bitstream/doc/24119/1/tese__diener_fernando.pdf

# %%
# arrumar (com o de cima) pois está pegando o campo url que pode conter textos (e não só urls)
# cuidar porque pode haver mais de uma
for nome_grupo, dados_grupo in dados_by_instituicao:
  print(f'Processando dados da: {nome_grupo}')
  print(dados_grupo)        
  
  url = list(dados_grupo['Link de acesso'])[0] 
  
  links = encontrar_links_pdf(url)  
  parsed_url = urlparse(url)
  servidor = parsed_url.netloc

  for link in links:
      print(f"https://{servidor}{link}")

  print('---')
# Out:
# Processando dados da: CPRM
#      Ano de defesa Sigla da instituição de defesa Tipo de documento  \
# 30            2023                           CPRM    doctoralThesis
# 45            2022                           CPRM      masterThesis
# 55            2021                           CPRM      masterThesis
# 56            2021                           CPRM      masterThesis
# 79            2023                           CPRM      masterThesis
# 147           2022                           CPRM    doctoralThesis
#
#                                  Link de acesso
# 30    https://rigeo.sgb.gov.br/handle/doc/24119
# 45   https://rigeo.cprm.gov.br/handle/doc/22892
# 55   https://rigeo.cprm.gov.br/handle/doc/22626
# 56   https://rigeo.cprm.gov.br/handle/doc/22659
# 79    https://rigeo.sgb.gov.br/handle/doc/24629
# 147  https://rigeo.cprm.gov.br/handle/doc/23433
# https://rigeo.sgb.gov.br/bitstream/doc/24119/1/tese__diener_fernando.pdf
# https://rigeo.sgb.gov.br/bitstream/doc/24119/1/tese__diener_fernando.pdf
# ---
# Processando dados da: CUB
#      Ano de defesa Sigla da instituição de defesa Tipo de documento  \
# 455           2021                            CUB      masterThesis
#
#                                         Link de acesso
# 455  https://repositorio.cruzeirodosul.edu.br/handl...
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'rigeo.sgb.gov.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---
# Processando dados da: FEI
#      Ano de defesa Sigla da instituição de defesa Tipo de documento  \
# 228           2022                            FEI      masterThesis
# 409           2022                            FEI      masterThesis
# 541           2023                            FEI      masterThesis
# 735           2021                            FEI      masterThesis
#
#                                         Link de acesso
# 228  LOPES, J. G. <b> Análise exergética de um sist...
# 409  NEVES, Mayara Alves Rosa. <b> Propriedades int...
# 541  CASTRO, João Vítor Mateika de. <b> Propriedade...
# 735  LUIS, Daniela Denleschi Fernandes. <b> Modelag...
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repositorio.cruzeirodosul.edu.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       3 print(dados_grupo)
#       5 url = list(dados_grupo['Link de acesso'])[0]
# ----> 7 links = encontrar_links_pdf(url)
#       8 parsed_url = urlparse(url)
#       9 servidor = parsed_url.netloc
#
# Input In [6], in encontrar_links_pdf(url)
#      31 def encontrar_links_pdf(url):
#      32   """
#      33   Encontra links para arquivos PDF em uma página web.
#      34
#    (...)
#      39     Uma lista de links para arquivos PDF.
#      40   """
# ---> 42   response = requests.get(url, verify=False)
#      43   soup = BeautifulSoup(response.content, 'html.parser')
#      45   links_pdf = []
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:695, in Session.send(self, request, **kwargs)
#     692 hooks = request.hooks
#     694 # Get the appropriate adapter to use
# --> 695 adapter = self.get_adapter(url=request.url)
#     697 # Start time (approximately) of the request
#     698 start = preferred_clock()
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:792, in Session.get_adapter(self, url)
#     789         return adapter
#     791 # Nothing matches :-/
# --> 792 raise InvalidSchema(f"No connection adapters were found for {url!r}")
#
# InvalidSchema: No connection adapters were found for 'LOPES, J. G. <b> Análise exergética de um sistema de compressão de CO2 de uma plataforma FPSO. </b> 2022. 146 f. Dissertação (Mestrado em Engenharia Mecânica) - Centro Universitário FEI, São Bernardo do campo, 2022 Disponível em: https://doi.org/10.31414/EM.2022.D.131393.||https://doi.org/10.31414/EM.2022.D.131393||https://repositorio.fei.edu.br/handle/FEI/4411'

# %%
# baixa os pdfs (ajustar pois não funciona ainda)
for recurso in dados_do_csv:
    identificador = ast.literal_eval(recurso['identifier'])

    pdf_sub_url = f"{identificador[0].removeprefix("http://hdl.handle.net")}/handle/{identificador[1]}"
    url_sufix = ".pdf?sequence=1&isAllowed=y"
    full_url = f"{server_url}{pdf_sub_url}{url_sufix}"

    print(f"Baixando PDF: {full_url}")

    nome_do_arquivo = f"{dados_do_csv[0]['type']}".removeprefix("['").removesuffix("']")
    nome_do_arquivo = f"{ast.literal_eval(dados_do_csv[0]['date'])[1]}_{nome_do_arquivo}_{identificador[1]}.pdf"

    baixar_pdf(full_url, nome_do_arquivo)

    time.sleep(1)
